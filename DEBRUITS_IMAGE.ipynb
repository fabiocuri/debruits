# %%
# !git clone https://github.com/fabiocuri/debruits.git
# Out:
# Cloning into 'debruits'...
# remote: Enumerating objects: 2818, done.
# remote: Counting objects: 100% (847/847), done.
# remote: Compressing objects: 100% (772/772), done.
# remote: Total 2818 (delta 73), reused 828 (delta 62), pack-reused 1971
# Receiving objects: 100% (2818/2818), 2.04 GiB | 59.07 MiB/s, done.
# Resolving deltas: 100% (253/253), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PIP_VERSION="pip3"
PYTHON_VERSION="python3"

# %%
BRIGHTNESS=0.9
CONTRAST=1.1
BLUR=2
SATURATION=1.3

# %%
N_EPOCHS=50

# %%
N_SUPER_RESOLUTION="2"

# %% [markdown]
# # Configure

# %%
# !$PIP_VERSION install -r /content/debruits/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 466 kB 43.1 MB/s
# ...
#      |████████████████████████████████| 950 kB 71.5 MB/s
# ...
#      |████████████████████████████████| 167 kB 91.8 MB/s
# ...
#      |████████████████████████████████| 4.5 MB 61.8 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 69.1 MB/s
# ...
#      |████████████████████████████████| 61 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 66.0 MB/s
# ...
#      |████████████████████████████████| 26.9 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 58.7 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 42.4 MB/s
# ...
#      |████████████████████████████████| 388 kB 93.0 MB/s
# ...

# %%
# !git clone https://github.com/idealo/image-super-resolution
# !cd image-super-resolution
# !$PYTHON_VERSION /content/image-super-resolution/setup.py install
# Out:
# fatal: destination path 'image-super-resolution' already exists and is not an empty directory.
# running install
# running bdist_egg
# running egg_info
# creating ISR.egg-info
# writing ISR.egg-info/PKG-INFO
# writing dependency_links to ISR.egg-info/dependency_links.txt
# writing requirements to ISR.egg-info/requires.txt
# writing top-level names to ISR.egg-info/top_level.txt
# writing manifest file 'ISR.egg-info/SOURCES.txt'
# reading manifest file 'ISR.egg-info/SOURCES.txt'
# writing manifest file 'ISR.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# ...
#
# creating build
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying ISR.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ISR.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ISR.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# ...

# %% [markdown]
# # Train

# %%
# !$PYTHON_VERSION /content/debruits/src/image/preprocess.py train $BRIGHTNESS $CONTRAST $BLUR $SATURATION
# !$PYTHON_VERSION /content/debruits/src/image/preprocess.py val $BRIGHTNESS $CONTRAST $BLUR $SATURATION
# !$PYTHON_VERSION /content/debruits/src/image/train.py start $N_EPOCHS
# Out:
# 2022-09-06 16:04:30.773713: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#   0% 0/4900 [00:00<?, ?it/s]>1, d1[0.282] d2[0.797] g[71.787]
#   0% 1/4900 [00:07<9:32:47,  7.02s/it]>2, d1[0.321] d2[0.355] g[70.879]
#   0% 2/4900 [00:07<4:04:10,  2.99s/it]>3, d1[0.362] d2[0.363] g[84.584]
#   0% 3/4900 [00:07<2:19:10,  1.71s/it]>4, d1[0.355] d2[0.154] g[56.698]
#   0% 4/4900 [00:07<1:29:46,  1.10s/it]>5, d1[0.467] d2[0.087] g[53.199]
#   0% 5/4900 [00:07<1:02:24,  1.31it/s]>6, d1[0.198] d2[0.045] g[50.823]
#   0% 6/4900 [00:07<45:47,  1.78it/s]  >7, d1[0.160] d2[0.033] g[47.806]
#   0% 7/4900 [00:08<35:25,  2.30it/s]>8, d1[0.138] d2[0.038] g[53.352]
# ...

# %%
# !$PYTHON_VERSION /content/debruits/src/image/train.py continue $N_EPOCHS
# Out:
# 2022-09-06 15:52:26.864631: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
#   0% 0/4900 [00:00<?, ?it/s]>1, d1[0.148] d2[1.343] g[29.979]
#   0% 1/4900 [00:05<6:58:25,  5.12s/it]>2, d1[0.103] d2[1.559] g[41.454]
#   0% 2/4900 [00:05<2:59:46,  2.20s/it]>3, d1[0.156] d2[1.375] g[38.174]
#   0% 3/4900 [00:05<1:43:22,  1.27s/it]>4, d1[0.181] d2[1.300] g[36.206]
#   0% 4/4900 [00:05<1:07:31,  1.21it/s]>5, d1[0.124] d2[1.532] g[22.711]
#   0% 5/4900 [00:05<47:34,  1.71it/s]  >6, d1[0.101] d2[1.311] g[25.750]
#   0% 6/4900 [00:05<35:39,  2.29it/s]>7, d1[0.101] d2[1.480] g[30.754]
# ...

# %% [markdown]
# # Inference

# %%
# !$PYTHON_VERSION /content/debruits/src/image/preprocess.py test $BRIGHTNESS $CONTRAST $BLUR $SATURATION
# !$PYTHON_VERSION /content/debruits/src/image/inference.py
# !$PYTHON_VERSION /content/debruits/src/image/super_resolution.py /content/drive/MyDrive/image/output/inference $N_SUPER_RESOLUTION
# !$PYTHON_VERSION /content/debruits/src/image/crop.py /content/drive/MyDrive/image/output/plots
# !$PYTHON_VERSION /content/debruits/src/image/super_resolution.py /content/drive/MyDrive/image/output/plots/cropped $N_SUPER_RESOLUTION
# Out:
# 100% 546/546 [00:21<00:00, 25.76it/s]
# 100% 546/546 [00:04<00:00, 129.97it/s]
# 100% 546/546 [00:01<00:00, 282.90it/s]
# 2022-09-06 16:24:07.592888: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100% 546/546 [00:44<00:00, 12.14it/s]
# 100% 546/546 [01:49<00:00,  4.99it/s]
# 100% 491/491 [00:21<00:00, 23.16it/s]
# 100% 1470/1470 [01:21<00:00, 18.06it/s]

# %% [markdown]
# # Split Video

# %%
# !$PYTHON_VERSION /content/debruits/src/image/split_video.py /content/drive/MyDrive/video/DSC_0022.mp4
# Out:
# True (1080, 1560, 3)
